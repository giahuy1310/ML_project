# %% [markdown]
# The [NO2 dataset](https://www.openml.org/d/547) contains 500 measurement of pollution caused by cars. The goal is to predict the concentration of $NO_2$ from data about traffic and atmospheric conditions. The predictive variables include the number of cars per hour, temperature, wind, and time of day.
# 1. Develop a regression model to predict nitrogen dioxide levels from the NO2 dataset containing 500 observations.
# 2. Understand the dataset, including features such as traffic volume (cars/hour), temperature, wind, and time of day.
# 3. Perform data preprocessing: handle missing values, normalize features, and encode time-related variables if needed.
# 4. Conduct exploratory data analysis to identify correlations between predictors and NO₂ concentration.
# 5. Implement baseline models such as Linear Regression to establish initial performance.
# 6. Extend to more advanced models like Decision Trees or Random Forest for better non-linear modeling.
# 7. Train models using appropriate loss functions (e.g., Mean Squared Error) and validate using cross-validation.
# 8. Evaluate performance using metrics such as RMSE and R², and analyze feature importance and prediction errors.
